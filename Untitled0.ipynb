# %%
#this is a comment

# %%
print("Hello write")
# Out:
# Hello write

# %%
print("3")
# Out:
# 3

# %%
print(2+2)
# Out:
# 4

# %%
5//2
# Out:
# 2

# %%
5//2
# Out:
# 2

# %%
5%2
# Out:
# 1

# %%
5/2.0
# Out:
# 2.5

# %%
int(7.0)
# Out:
# 7

# %%
"Hello"+ "World"
# Out:
# 'HelloWorld'

# %%
5* "Hello"
# Out:
# 'HelloHelloHelloHelloHello'

# %%
a= "hello"
b= "world"
a+b
# Out:
# 'helloworld'

# %%
a=1
a
# Out:
# 1

# %%
a=a+2

# %%
a==a
# Out:
# True

# %%
2>1
# Out:
# True

# %%
2>3
# Out:
# False

# %%
a and b
# Out:
# 'world'

# %%
a or b
# Out:
# 3

# %%
#This is a list

# %%
print("Python for Gis data analysis")
# Out:
# Python for Gis data analysis
