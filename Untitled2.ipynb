# %%
a={1, dollar, one, Buga, key}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1c6dcc0535d6> in <cell line: 1>()
# ----> 1 a={1, dollar, one, Buga, key}
#
# NameError: name 'dollar' is not defined

# %%
a=
